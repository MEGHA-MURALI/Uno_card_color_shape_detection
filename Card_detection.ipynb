# %%
# Install and Import Dependencies

# %%
#!pip install torch==1.8.1+cu111 torchvision==0.9.1+cu111 torchaudio===0.8.1 -f https://download.pytorch.org/whl/lts/1.8/torch_lts.html

# %%
#!git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...

# %%
#!pip install -r yolov5/requirements.txt
# Out:
# ...
#      ---------------------------------------- 7.2/7.2 MB 27.1 MB/s eta 0:00:00
# ...
#   Using cached opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
# ...
#   Using cached PyYAML-6.0-cp38-cp38-win_amd64.whl (155 kB)
# ...
#   Using cached requests-2.28.1-py3-none-any.whl (62 kB)
# ...
#      --------------------------------------- 39.8/39.8 MB 16.8 MB/s eta 0:00:00
# ...
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# ...
#   Using cached tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
# ...
#      --------------------------------------- 11.0/11.0 MB 40.9 MB/s eta 0:00:00
# ...
#      -------------------------------------- 288.2/288.2 kB 9.0 MB/s eta 0:00:00
# ...
#      ------------------------------------- 761.1/761.1 kB 16.0 MB/s eta 0:00:00
# ...
#      ------------------------------------- 248.0/248.0 kB 14.9 MB/s eta 0:00:00
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...
#      -------------------------------------- 163.5/163.5 kB 2.4 MB/s eta 0:00:00
# ...

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
# !cd yolov5 && python train.py --img 640 --batch 4 --epochs 40 --data data_card.yaml --weights yolov5s.pt --hyp hyp.scratch-low.yaml --workers 2
# Out:
# requirements: C:\Users\NyblAdmin\Desktop\Card_detection\requirements.txt not found, check failed.
# train: weights=yolov5s.pt, cfg=, data=data_card.yaml, hyp=hyp.scratch-low.yaml, epochs=40, batch_size=4, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5
# YOLOv5  v7.0-155-g8ecc727 Python-3.8.13 torch-1.8.1+cu111 CUDA:0 (Tesla K80, 11448MiB)
#
# ...

# %%
# !cd yolov5 && python detect.py --weights runs/train/exp/weights/best.pt --source data/test
# Out:
# requirements: C:\Users\NyblAdmin\Desktop\Card_detection\requirements.txt not found, check failed.
# detect: weights=['runs/train/exp/weights/best.pt'], source=data/test, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-155-g8ecc727 Python-3.8.13 torch-1.8.1+cu111 CUDA:0 (Tesla K80, 11448MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/660) C:\Users\NyblAdmin\Desktop\Card_detection\yolov5\data\test\test.MOV: 384x640 1 card, 31.3ms
# video 1/1 (2/660) C:\Users\NyblAdmin\Desktop\Card_detection\yolov5\data\test\test.MOV: 384x640 1 card, 31.2ms
# ...
